# %%
import numpy as np
a=np.array([5,8,4,7])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
a=np.array([5,8,4,7])
a.shape
a.ndim
# Out:
# 1

# %%
import numpy as np
a=np.array([[5,8,4,7],[2,3,9,6]])
a.shape
a.ndim
# Out:
# 2

# %%
import numpy as np
a=np.array([[5,8,4,7],[2,3,9,6]])
a[:,::-1]#reverse
# Out:
# array([[7, 4, 8, 5],
#        [6, 9, 3, 2]])

# %%
import numpy as np
a=np.array([[5,8,4,7],[2,3,9,6]])
a.T #combiningle single ele from each arr with their respective pos
# Out:
# array([[5, 2],
#        [8, 3],
#        [4, 9],
#        [7, 6]])

# %%
import numpy as np
a=np.array([[5,8,4,7],[2,3,9,6]])
np.std(a)#standard deviation
# Out:
# np.float64(2.29128784747792)

# %%
np.std(a, axis=0)  # column-wise
np.std(a, axis=1)  # row-wise #variance
# Out:
# array([1.58113883, 2.73861279])

# %%
import numpy as np
a= np.array([3,2,6])
b=np.array([2,9,7])
np.add(a,b)
np.multiply(a,b)
np.divide(a,b)
# Out:
# array([1.5       , 0.22222222, 0.85714286])

# %%
import pandas as pd
import numpy as np
f={
    "d":[6,7,9]
}
f
# Out:
# {'d': [6, 7, 9]}

# %%
import pandas as pd
import numpy as np
f={
    "d":[6,7,9,np.nan],
    "a":[4,3,2,np.nan]
}
df=pd.DataFrame(f)
df
# Out:
#      d    a
# 0  6.0  4.0
# 1  7.0  3.0
# 2  9.0  2.0
# 3  NaN  NaN

# %%
import pandas as pd
import numpy as np
f={
    "d":[np.nan,7,9,np.nan],
    "a":[4,3,2,np.nan],
    "k":[2,66,11,np.nan]
}
df=pd.DataFrame(f)
df
# Out:
#      d    a     k
# 0  NaN  4.0   2.0
# 1  7.0  3.0  66.0
# 2  9.0  2.0  11.0
# 3  NaN  NaN   NaN

# %%
df.isnull().sum()
# Out:
# d    1
# a    1
# dtype: int64

# %%
df["d"]
# Out:
# 0    NaN
# 1    7.0
# 2    9.0
# 3    NaN
# Name: d, dtype: float64

# %%
df["d"].fillna(7,inplace=True)
df
# Out:
#      d    a     k
# 0  7.0  4.0   2.0
# 1  7.0  3.0  66.0
# 2  9.0  2.0  11.0
# 3  7.0  NaN   NaN

# %%
import pandas as pd
import numpy as np
f={
    "d":[np.nan,7,9,np.nan],
    "a":[4,3,2,np.nan],
    "k":[2,66,11,np.nan]
}
df=pd.DataFrame(f)
df["a"].fillna(df['a'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-4-1969404693.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["a"].fillna(df['a'].mean(),inplace=True)
#      d    a     k
# 0  NaN  4.0   2.0
# 1  7.0  3.0  66.0
# 2  9.0  2.0  11.0
# 3  NaN  3.0   NaN

# %%
import pandas as pd
import numpy as np
f={
    "d":[np.nan,7,9,np.nan],
    "a":[4,3,2,np.nan],
    "k":[2,66,11,np.nan]
}
df=pd.DataFrame(f)
df["k"].fillna(df['k'].mode(),inplace=True)
df
# Out:
# /tmp/ipython-input-5-842621272.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["k"].fillna(df['k'].mode(),inplace=True)
#      d    a     k
# 0  NaN  4.0   2.0
# 1  7.0  3.0  66.0
# 2  9.0  2.0  11.0
# 3  NaN  NaN   NaN

# %%
d={
    'l':[5,np.nan,8,4,2,np.nan],
    'j':['g','l','a','l',np.nan, np.nan]
}
df=pd.DataFrame(d)
df
# Out:
#      l    j
# 0  5.0    g
# 1  NaN    l
# 2  8.0    a
# 3  4.0    l
# 4  2.0  NaN
# 5  NaN  NaN

# %%
import pandas as pd
import numpy as np
f={
    "age":[18,19,18,29],
    "name":['komali','futureDealer','komali','jyo']
}
df=pd.DataFrame(f)
df
# Out:
#    age          name
# 0   18        komali
# 1   19  futureDealer
# 2   18        komali
# 3   29           jyo

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    age    name
# 2   18  komali

# %%
df.drop_duplicates(subset='age',inplace=True)
df
# Out:
#    age          name
# 0   18        komali
# 1   19  futureDealer
# 3   29           jyo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     3 non-null      int64
#  1   name    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 72.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   22.000000
# std     6.082763
# min    18.000000
# 25%    18.500000
# 50%    19.000000
# 75%    24.000000
# max    29.000000

# %%
import pandas as pd
import numpy as np
f={
    "age":[18,19,20],
    "name":['low','medium','high']
}
df=pd.DataFrame(f)
df
# Out:
#    age    name
# 0   18     low
# 1   19  medium
# 2   20    high

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['name']=le.fit_transform(df[['name']])
df
# Out:
#         age  name
# 0 -1.224745     1
# 1  0.000000     2
# 2  1.224745     0

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
df['level']=le.fit_transform(df[['evel']])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-61-1692597359.py in <cell line: 0>()
#       1 from sklearn.preprocessing import LabelEncoder,OneHotEncoder
#       2 le=LabelEncoder()
# ----> 3 df['level']=le.fit_transform(df[['evel']])
#       4 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mm=StandardScaler() # Create an instance of StandardScaler
df['age']=mm.fit_transform(df[['age']])
df
# Out:
#         age    name
# 0 -1.224745     low
# 1  0.000000  medium
# 2  1.224745    high

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mm=StandardScaler() # Create an instance of StandardScaler
df['age']=mm.fit_transform(df[['age']])
df.describe()
# Out:
#             age  name
# count  3.000000   3.0
# mean   0.000000   1.0
# std    1.224745   1.0
# min   -1.224745   0.0
# 25%   -0.612372   0.5
# 50%    0.000000   1.0
# 75%    0.612372   1.5
# max    1.224745   2.0

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df
# Out:
#    Car_Brand Fuel_Type  Kilometers_Driven  Engine_CC  Seats  Year Automatic  \
# 0      Honda    Diesel            75725.0       1000      5  2017       Yes
# 1     Maruti    Diesel            94654.0       1200      5  2019       Yes
# 2      Honda       NaN            45773.0       1200      5  2018       Yes
# 3      Honda    Petrol            77435.0        800      5  2021       Yes
# 4     Maruti    Diesel           300000.0       1200      4  2021       Yes
# 5     Maruti    Diesel                NaN       1200      5  2021        No
# 6      Honda    Diesel            41551.0       1000      4  2018       Yes
# 7    Hyundai    Petrol            21394.0        800      5  2010        No
# 8      Honda    Diesel            79092.0       1000      5  2018       Yes
# 9      Honda    Petrol            13890.0       1000      4  2016        No
# 10     Honda    Petrol            51606.0       1000      5  2018       Yes
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df.tail()
# Out:
#    Car_Brand Fuel_Type  Kilometers_Driven  Engine_CC  Seats  Year Automatic  \
# 15    Maruti    Diesel            83969.0        800      5  2017       Yes
# 16   Hyundai    Diesel            53001.0       1200      4  2020        No
# 17   Hyundai    Diesel            86552.0       1000      5  2012       Yes
# 18   Hyundai    Diesel            33897.0       1000      4  2010       Yes
# 19   Hyundai    Petrol            78148.0       1000      4  2017        No
#
#     Owner_Count   Price
# 15            1  579989
# 16            2  615515
# 17            1  243585
# 18            1  571369
# 19            2  264044

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_Brand          20 non-null     object
#  1   Fuel_Type          19 non-null     object
#  2   Kilometers_Driven  19 non-null     float64
#  3   Engine_CC          20 non-null     int64
#  4   Seats              20 non-null     int64
#  5   Year               20 non-null     int64
#  6   Automatic          20 non-null     object
#  7   Owner_Count        20 non-null     int64
#  8   Price              20 non-null     int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 1.5+ KB

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df.describe()
# Out:
#        Kilometers_Driven    Engine_CC      Seats         Year  Owner_Count  \
# count          19.000000    20.000000  20.000000    20.000000     20.00000
# mean        71760.894737  1020.000000   4.600000  2016.900000      1.35000
# std         62003.803854   128.144655   0.502625     3.654845      0.48936
# min         13890.000000   800.000000   4.000000  2010.000000      1.00000
# 25%         37724.000000  1000.000000   4.000000  2016.750000      1.00000
# 50%         75725.000000  1000.000000   5.000000  2017.500000      1.00000
# 75%         85260.500000  1050.000000   5.000000  2019.250000      2.00000
# max        300000.000000  1200.000000   5.000000  2021.000000      2.00000
#
#               Price
# count  2.000000e+01
# mean   5.254853e+05
# std    4.861235e+05
# min    2.435850e+05
# 25%    3.170538e+05
# 50%    3.918130e+05
# 75%    5.735240e+05
# max    2.500000e+06

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df[['Car_Brand',"Year"]]
# Out:
#    Car_Brand  Year
# 0      Honda  2017
# 1     Maruti  2019
# 2      Honda  2018
# 3      Honda  2021
# 4     Maruti  2021
# 5     Maruti  2021
# 6      Honda  2018
# 7    Hyundai  2010
# 8      Honda  2018
# 9      Honda  2016
# 10     Honda  2018
# 11     Honda  2017
# 12    Maruti  2010
# 13     Honda  2021
# 14   Hyundai  2017
# 15    Maruti  2017
# 16   Hyundai  2020
# 17   Hyundai  2012
# 18   Hyundai  2010
# 19   Hyundai  2017

# %%
import pandas as pd
df=pd.read_csv("/content/simple_used_car_dataset.csv")
df

# %%
df.isnull().sum()
# Out:
# Car_Brand            0
# Fuel_Type            1
# Kilometers_Driven    1
# Engine_CC            0
# Seats                0
# Year                 0
# Automatic            0
# Owner_Count          0
# Price                0
# dtype: int64

# %%
df['Fuel_Type'].fillna(df['Fuel_Type'].mode()[0],inplace=True)
df
# Out:
#    Car_Brand Fuel_Type  Kilometers_Driven  Engine_CC  Seats  Year Automatic  \
# 0      Honda    Diesel            75725.0       1000      5  2017       Yes
# 1     Maruti    Diesel            94654.0       1200      5  2019       Yes
# 2      Honda    Diesel            45773.0       1200      5  2018       Yes
# 3      Honda    Petrol            77435.0        800      5  2021       Yes
# 4     Maruti    Diesel           300000.0       1200      4  2021       Yes
# 5     Maruti    Diesel                NaN       1200      5  2021        No
# 6      Honda    Diesel            41551.0       1000      4  2018       Yes
# 7    Hyundai    Petrol            21394.0        800      5  2010        No
# 8      Honda    Diesel            79092.0       1000      5  2018       Yes
# 9      Honda    Petrol            13890.0       1000      4  2016        No
# 10     Honda    Petrol            51606.0       1000      5  2018       Yes
# ...

# %%
df['Fuel_Type'].fillna(df['Fuel_Type'].mode()[0],inplace=True)
df['Kilometers_Driven'].fillna(df['Kilometers_Driven'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Car_Brand            0
# Fuel_Type            0
# Kilometers_Driven    0
# Engine_CC            0
# Seats                0
# Year                 0
# Automatic            0
# Owner_Count          0
# Price                0
# dtype: int64

# %%
#duplicate values
#df.duplicated().sum()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Car_Brand, Fuel_Type, Kilometers_Driven, Engine_CC, Seats, Year, Automatic, Owner_Count, Price]
# Index: []

# %%
#treatment of duplicates there are no duplicates value
df.drop_duplicates(subset='Year',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Fuel_Type']=le.fit_transform(df[['Fuel_Type']])
display(df)
# Out:
#    Car_Brand  Fuel_Type  Kilometers_Driven  Engine_CC  Seats  Year Automatic  \
# 0      Honda          0            75725.0       1000      5  2017       Yes
# 1     Maruti          0            94654.0       1200      5  2019       Yes
# 2      Honda          0            45773.0       1200      5  2018       Yes
# 3      Honda          1            77435.0        800      5  2021       Yes
# 7    Hyundai          1            21394.0        800      5  2010        No
# 9      Honda          1            13890.0       1000      4  2016        No
# 16   Hyundai          0            53001.0       1200      4  2020        No
# 17   Hyundai          0            86552.0       1000      5  2012       Yes
#
#     Owner_Count    Price
# 0             2   319176
# 1             1  2500000
# 2             1   418969
# 3             2   322409
# 7             1   322096
# 9             1   310687
# 16            2   615515
# 17            1   243585

# %%
from sklearn.preprocessing import minmax_scale,StandardScaler
mm=MinMaxScaler()
df['Kilometers_Driven']=mm.fit_transform(df[['Kilometers_Driven']])
df
# Out:
#   Car_Brand  Fuel_Type  Kilometers_Driven  Engine_CC  Seats  Year Automatic  \
# 0     Honda          0           0.765626       1000      5  2017       Yes
# 1    Maruti          0           1.000000       1200      5  2019       Yes
# 2     Honda          0           0.394767       1200      5  2018       Yes
# 3     Honda          1           0.786799        800      5  2021       Yes
# 4   Hyundai          1           0.092913        800      5  2010        No
# 5     Honda          1           0.000000       1000      4  2016        No
# 6   Hyundai          0           0.484263       1200      4  2020        No
# 7   Hyundai          0           0.899683       1000      5  2012       Yes
#
#    Owner_Count    Price  Automatic_Yes
# 0            2   319176            1.0
# 1            1  2500000            1.0
# 2            1   418969            1.0
# 3            2   322409            1.0
# 4            1   322096            0.0
# 5            1   310687            0.0
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([2,4,6,7],color='red',linestyle='--')
#uni varient
plt.title("label")
plt.xlabel("x-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar([2,4,6,7],[7,8,9,9])
#uni varient
plt.title("label")
plt.xlabel("x-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,4,6,7]
y=[7,8,9,9]
#uni varient
plt.barh(x,y)
plt.title("label")
plt.xlabel("x-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,4,6,7]
y=[7,8,9,9]
#bivarient
plt.scatter(x,y)
plt.title("label")
plt.xlabel("x-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,4,6,7]
y=[7,8,9,9]
plt.hist(x,y)
plt.title("label")
plt.xlabel("x-axis")
plt.show()

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.pie(x,y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.pie(x,y,hole=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.histogram(x,y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.funnel(x,y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.funnel_area(x,y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
x=[2,4,6,7]
y=[7,8,9,9]
px.treemap(x,y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
